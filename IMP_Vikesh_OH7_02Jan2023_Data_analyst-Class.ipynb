# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Imperial Business Analytics- WK8- Estimators
#
#  👨‍🏫 **Vikesh K**
#  📅 **[02-Jan-2023]** ⏰ **7pm UTC**
#  #️⃣ **Office Hour # 07**
#
#
#
# </div>

# %% [markdown]
#  💡  <span style='font-family:Georgia'>
#     <font color= darkred> ***It doesn't get easier, you get better- Unknown***
#     </font> 💡

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics--WK8--Estimators" data-toc-modified-id="Imperial-Business-Analytics--WK8--Estimators-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics- WK8- Estimators</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#▶️-Theory" data-toc-modified-id="▶️-Theory-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>▶️ Theory</a></span></li><li><span><a href="#Case-Study-📓---Instacart" data-toc-modified-id="Case-Study-📓---Instacart-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Case Study 📓 - Instacart</a></span><ul class="toc-item"><li><span><a href="#Note:-✨" data-toc-modified-id="Note:-✨-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Note: ✨</a></span></li><li><span><a href="#Loading-the-modules" data-toc-modified-id="Loading-the-modules-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Loading the modules</a></span></li></ul></li><li><span><a href="#Exercises-💥⚡" data-toc-modified-id="Exercises-💥⚡-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exercises 💥⚡</a></span><ul class="toc-item"><li><span><a href="#Importing-the-data" data-toc-modified-id="Importing-the-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Importing the data</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Data Cleaning</a></span></li><li><span><a href="#Exploring-the-delivery-time-across-regions" data-toc-modified-id="Exploring-the-delivery-time-across-regions-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Exploring the delivery time across regions</a></span><ul class="toc-item"><li><span><a href="#Plot-the-deliveries-in-sf" data-toc-modified-id="Plot-the-deliveries-in-sf-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Plot the deliveries in <code>sf</code></a></span></li><li><span><a href="#Plot-the-deliveries-in-all-regions" data-toc-modified-id="Plot-the-deliveries-in-all-regions-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Plot the deliveries in all regions</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # OH Agenda 📝
#
# * **Instacart case study** : Analysing an open ended data analytics problem
# * Understanding the time series in pandas
# * Coding exercises 💥⚡
#
# <div/>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # ▶️ Theory
#
#
#
#
# **Data Science reality**
#
# ![data_science_reality.png](attachment:data_science_reality.png)

# %% [markdown]
# # Case Study 📓 - Instacart
#
# ![instacart_logo.png](attachment:instacart_logo.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Note: ✨
#
# A **take-home assignment** is a coding task given to candidates to complete on their own time. Candidates are typically given a day to several days to complete a take-home. It is done to understand a candidate's problem solving approach and how they structure a business problem, solve it using data and give back business recommendations.
#
# In this OH, we will analyze a problem posed by [**Instacart**](https://www.instacart.com/) for its Data Analyst position. You can see the Case Study [here](https://docs.google.com/document/d/1ShmBy2tPHJM0BWCAhhZjy1LL90r43aCPS_pJauoiyZE/edit)
#
# <div/>

# %% [markdown]
# 💡 **We will learn about the data used by delivery companies and how they analyze it to solve their business problems**

# %% [markdown]
# ## Loading the modules

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import os 
os.getcwd() # make sure the zip file is saved in the working directory
# Out:
# 'C:\\Users\\Hakim Aljanabi\\Downloads'

# %% [markdown]
# # Exercises 💥⚡

# %% [markdown]
# ## Importing the data

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/instacart.csv'

df = pd.read_csv(url)
orig_df = df # create a copy of the original data-frame

# %% [markdown]
# ## Data Cleaning

# %%
df.head()
# Out:
#        order_delivery_time   order_id  customer_order_rating  \
# 0  2014-06-02 04:23:16 UTC  233599337                      5
# 1  2014-06-02 03:57:50 UTC  233599376                      5
# 2  2014-06-02 02:52:38 UTC  233599328                      5
# 3  2014-06-02 02:52:04 UTC  233599070                      5
# 4  2014-06-02 02:41:43 UTC  233599100                      5
#
#   type_of_issue _reported region
# 0                     NaN    chi
# 1                     NaN    chi
# 2                     NaN    chi
# 3                     NaN    chi
# 4                     NaN    chi

# %%
df.isnull().sum()
# Out:
# order_delivery_time            0
# order_id                       0
# customer_order_rating          0
# type_of_issue _reported    13870
# region                         0
# dtype: int64

# %% [markdown]
# ## Exploring the delivery time across regions

# %% [markdown]
# 💡**We can extract different elements from a time column like date, hour, minutes, weekday etc. We will extract the hour**

# %% [markdown]
# ### Plot the deliveries in `sf`

# %%
df.head()
# Out:
#        order_delivery_time   order_id  customer_order_rating  \
# 0  2014-06-02 04:23:16 UTC  233599337                      5
# 1  2014-06-02 03:57:50 UTC  233599376                      5
# 2  2014-06-02 02:52:38 UTC  233599328                      5
# 3  2014-06-02 02:52:04 UTC  233599070                      5
# 4  2014-06-02 02:41:43 UTC  233599100                      5
#
#   type_of_issue _reported region
# 0                     NaN    chi
# 1                     NaN    chi
# 2                     NaN    chi
# 3                     NaN    chi
# 4                     NaN    chi

# %%
df['region'].unique()
# Out:
# array(['chi', 'nyc', 'sf', 'sf '], dtype=object)

# %%
df['region'].replace('sf ','sf')
# Out:
# 0        chi
# 1        chi
# 2        chi
# 3        chi
# 4        chi
#         ...
# 14952     sf
# 14953     sf
# 14954     sf
# 14955     sf
# 14956     sf
# Name: region, Length: 14957, dtype: object

# %%
df['region'] = df['region'].str.strip()

# %%
df['region'].unique()
# Out:
# array(['chi', 'nyc', 'sf'], dtype=object)

# %% [markdown]
# ### Plot the deliveries in all regions

# %% [markdown]
# **Using a loop to generate multiple charts**: We can use the above code used and put it in a loop to plot for all the regions

# %%
df['region'].value_counts()
# Out:
# sf     7237
# chi    6430
# nyc    1290
# Name: region, dtype: int64

# %%
df['order_delivery_time'] = pd.to_datetime(df['order_delivery_time'])

# %%
df.columns =['order_delivery_time', 'order_id', 'customer_order_rating',
       'type_of_issue_reported', 'region']

# %%
df.duplicated().sum()
# Out:
# 123

# %%
df.drop_duplicates(inplace= True)

# %%
df[df['order_id'].duplicated(keep=False)].sort_values(by='order_id').to_csv('test.data.csv')

# %%
sns.countplot(df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sns.countplot(x='customer_order_rating',hue='region',data=df)
# Out:
# <AxesSubplot:xlabel='customer_order_rating', ylabel='count'>

# %%
sns.scatterplot(x='customer_order_rating',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='customer_order_rating', ylabel='region'>

# %%
df['issue'] = df['type_of_issue_reported'].isnull()

# %%
df[df['issue']==False].to_csv('issue1.csv')

# %%
df2 = pd.read_csv('issue.csv')

# %%
df2
# Out:
#      Unnamed: 0        order_delivery_time   order_id  customer_order_rating  \
# 0            48  2014-06-02 00:18:47+00:00  233598909                      5
# 1            74  2014-06-01 23:28:59+00:00  233598602                      5
# 2            79  2014-06-01 23:17:41+00:00  233593711                      5
# 3           230  2014-06-01 17:24:55+00:00  233597308                      5
# 4           248  2014-06-01 17:01:53+00:00  233596310                      5
# ..          ...                        ...        ...                    ...
# 959       14903  2014-05-02 20:20:06+00:00  233614416                      1
# 960       14906  2014-05-01 17:25:32+00:00  233614431                      1
# 961       14907  2014-05-01 17:25:32+00:00  233614436                      1
# 962       14908  2014-05-01 17:25:32+00:00  233614441                      1
# 963       14924  2014-05-21 20:30:51+00:00  233614521                      0
#
#        type_of_issue_reported region  issue
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **The order delivery trend look odd. Most of the order seems to be happening at very early hours. You will notice that the `order_delivery_time` is currently measure in the UTC format. We would need to convert it to a local time zone based on the location before we can do our data analysis. We will use `dt.tz_convert()` within pandas to do this. As an argument, we specify the time zone to which it needs to be converted**
#
# <div/>

# %% [markdown]
# **We can change the time zones. The options we will choose are : `US/Eastern`, `US/Pacific`, `US/Central`**

# %% [markdown]
# ![us_time_zone-3.jpg](attachment:us_time_zone-3.jpg)

# %%
chi=df[df['region']=='chi']

# %%
sf= df[df['region']=='sf']

# %%
df[df['region']=='nyc']
# Out:
#            order_delivery_time   order_id  customer_order_rating  \
# 6430 2014-06-02 02:33:02+00:00  233599247                      5
# 6431 2014-06-02 01:31:11+00:00  233598545                      5
# 6432 2014-06-02 01:20:37+00:00  233598831                      5
# 6433 2014-06-01 23:31:22+00:00  233598712                      5
# 6434 2014-06-01 23:25:49+00:00  233598480                      5
# ...                        ...        ...                    ...
# 7715 2014-05-28 18:18:01+00:00  233591734                      0
# 7716 2014-05-19 16:20:27+00:00     246065                      0
# 7717 2014-05-18 21:45:49+00:00     246761                      0
# 7718 2014-05-10 22:00:58+00:00     234549                      0
# 7719 2014-05-08 20:21:58+00:00     231522                      0
#
#      type_of_issue_reported region  issue
# 6430                    NaN    nyc   True
# 6431                    NaN    nyc   True
# 6432                    NaN    nyc   True
# ...

# %%
nyc = df[df['region']=='nyc']

# %%
nyc['order_delivery_time']=nyc['order_delivery_time'].dt.tz_convert('US/eastern')

# %%
nyc
# Out:
#            order_delivery_time   order_id  customer_order_rating  \
# 6430 2014-06-01 22:33:02-04:00  233599247                      5
# 6431 2014-06-01 21:31:11-04:00  233598545                      5
# 6432 2014-06-01 21:20:37-04:00  233598831                      5
# 6433 2014-06-01 19:31:22-04:00  233598712                      5
# 6434 2014-06-01 19:25:49-04:00  233598480                      5
# ...                        ...        ...                    ...
# 7715 2014-05-28 14:18:01-04:00  233591734                      0
# 7716 2014-05-19 12:20:27-04:00     246065                      0
# 7717 2014-05-18 17:45:49-04:00     246761                      0
# 7718 2014-05-10 18:00:58-04:00     234549                      0
# 7719 2014-05-08 16:21:58-04:00     231522                      0
#
#      type_of_issue_reported region  issue
# 6430                    NaN    nyc   True
# 6431                    NaN    nyc   True
# 6432                    NaN    nyc   True
# ...

# %%
chi['order_delivery_time']=chi['order_delivery_time'].dt.tz_convert('US/Central')

# %%
sf['order_delivery_time']=sf['order_delivery_time'].dt.tz_convert('US/Pacific')

# %%
sf['month']=sf['order_delivery_time'].dt.month
sf['year']=sf['order_delivery_time'].dt.year
sf['hour']=sf['order_delivery_time'].dt.hour

# %%
sf['day']=sf['order_delivery_time'].dt.dayofweek

# %%
sf
# Out:
#             order_delivery_time   order_id  customer_order_rating  \
# 7720  2014-06-01 23:16:19-07:00  233599504                      5
# 7721  2014-06-01 22:58:10-07:00  233599318                      5
# 7722  2014-06-01 22:47:00-07:00  233599434                      5
# 7723  2014-06-01 22:42:17-07:00  233599167                      5
# 7724  2014-06-01 22:40:08-07:00  233599356                      5
# ...                         ...        ...                    ...
# 14952 2014-05-07 13:29:32-07:00  233614661                      0
# 14953 2014-05-05 16:59:17-07:00  233614666                      0
# 14954 2014-05-04 15:48:29-07:00  233614671                      0
# 14955 2014-05-03 10:41:36-07:00  233614676                      0
# 14956 2014-05-01 16:25:46-07:00  233614681                      0
#
#       type_of_issue_reported region  issue  month  year  hour  day
# 7720                     NaN     sf   True      6  2014    23    6
# ...

# %%
chi['month']=chi['order_delivery_time'].dt.month
chi['year']=chi['order_delivery_time'].dt.year
chi['hour']=chi['order_delivery_time'].dt.hour
chi['day']=chi['order_delivery_time'].dt.dayofweek

# %%
nyc['month']=nyc['order_delivery_time'].dt.month
nyc['year']=nyc['order_delivery_time'].dt.year
nyc['hour']=nyc['order_delivery_time'].dt.hour
nyc['day']=nyc['order_delivery_time'].dt.dayofweek

# %%
new_df = pd.concat([chi,nyc,sf])

# %%
sns.barplot(x='hour',y='customer_order_rating',data=new_df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='customer_order_rating'>

# %%
new_df
# Out:
#              order_delivery_time   order_id  customer_order_rating  \
# 0      2014-06-01 23:23:16-05:00  233599337                      5
# 1      2014-06-01 22:57:50-05:00  233599376                      5
# 2      2014-06-01 21:52:38-05:00  233599328                      5
# 3      2014-06-01 21:52:04-05:00  233599070                      5
# 4      2014-06-01 21:41:43-05:00  233599100                      5
# ...                          ...        ...                    ...
# 14952  2014-05-07 13:29:32-07:00  233614661                      0
# 14953  2014-05-05 16:59:17-07:00  233614666                      0
# 14954  2014-05-04 15:48:29-07:00  233614671                      0
# 14955  2014-05-03 10:41:36-07:00  233614676                      0
# 14956  2014-05-01 16:25:46-07:00  233614681                      0
#
#       type_of_issue_reported region  issue  month  year  hour  day
# 0                        NaN    chi   True      6  2014    23    6
# ...

# %%
sns.barplot(x='day',y='customer_order_rating',data=new_df,hue='region')
# Out:
# <AxesSubplot:xlabel='day', ylabel='customer_order_rating'>

# %%
new_df[new_df['issue']==False]['hour']
# Out:
# 48       19
# 74       18
# 79       18
# 230      12
# 248      12
#          ..
# 14903    13
# 14906    10
# 14907    10
# 14908    10
# 14924    13
# Name: hour, Length: 964, dtype: int64

# %%
new_df.head(1000)
# Out:
#             order_delivery_time   order_id  customer_order_rating  \
# 0     2014-06-01 23:23:16-05:00  233599337                      5
# 1     2014-06-01 22:57:50-05:00  233599376                      5
# 2     2014-06-01 21:52:38-05:00  233599328                      5
# 3     2014-06-01 21:52:04-05:00  233599070                      5
# 4     2014-06-01 21:41:43-05:00  233599100                      5
# ...                         ...        ...                    ...
# 996   2014-05-27 17:38:53-05:00  233590246                      5
# 997   2014-05-27 17:36:29-05:00  233590738                      5
# 998   2014-05-27 17:34:27-05:00  233590750                      5
# 999   2014-05-27 17:33:54-05:00  233590746                      5
# 1000  2014-05-27 17:31:19-05:00  233590165                      5
#
#      type_of_issue_reported region  issue  month  year  hour  day
# 0                       NaN    chi   True      6  2014    23    6
# ...

# %%
df.head(1000)
# Out:
#            order_delivery_time   order_id  customer_order_rating  \
# 0    2014-06-02 04:23:16+00:00  233599337                      5
# 1    2014-06-02 03:57:50+00:00  233599376                      5
# 2    2014-06-02 02:52:38+00:00  233599328                      5
# 3    2014-06-02 02:52:04+00:00  233599070                      5
# 4    2014-06-02 02:41:43+00:00  233599100                      5
# ...                        ...        ...                    ...
# 996  2014-05-27 22:38:53+00:00  233590246                      5
# 997  2014-05-27 22:36:29+00:00  233590738                      5
# 998  2014-05-27 22:34:27+00:00  233590750                      5
# 999  2014-05-27 22:33:54+00:00  233590746                      5
# 1000 2014-05-27 22:31:19+00:00  233590165                      5
#
#      type_of_issue_reported region  issue
# 0                       NaN    chi   True
# 1                       NaN    chi   True
# 2                       NaN    chi   True
# ...
